# %%
spark.conf.set(
    "fs.azure.account.key.shadowrevenuedatalake.dfs.core.windows.net",
    "KEY"
)

# %%
orders = spark.read.csv("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/orders.csv", header=True, inferSchema=True)
payments = spark.read.csv("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/payments.csv", header=True, inferSchema=True)
products = spark.read.csv("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/products.csv", header=True, inferSchema=True)
customers = spark.read.csv("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/customers.csv", header=True, inferSchema=True)

print(orders.count(), payments.count(), products.count(), customers.count())
# Out:
# 20400 18600 200 2000

# %%
orders.write.format("delta").mode("overwrite").save("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/delta/orders")

payments.write.format("delta").mode("overwrite").save("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/delta/payments")

products.write.format("delta").mode("overwrite").save("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/delta/products")

customers.write.format("delta").mode("overwrite").save("abfss://bronze@shadowrevenuedatalake.dfs.core.windows.net/delta/customers")
